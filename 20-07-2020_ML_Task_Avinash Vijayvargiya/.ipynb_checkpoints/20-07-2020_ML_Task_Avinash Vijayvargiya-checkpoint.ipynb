# %% [markdown]
# ### Libraries Used

# %%
# for handling Database
import pandas as pd
# Powerful tool for handling multi dimensional array
import numpy as np

# %% [markdown]
# ### Loading the Dataset into a Dataframe

# %%
#Reads a comma-separated values (csv) file into a DataFrame.
df = pd.read_csv("house_data.csv")
# Here,'house_data.csv' is loaded into a Dataframe named 'df'

# %%
#Returns no of rows and columns in dataframe
df.shape
#OR
rows, columns = df.shape

# %%
#Statistical info about Dataframe
df.describe()
# Out:
#                  id         price   bedrooms  bathrooms  sqft_living  \
# count  9.900000e+01  9.900000e+01  99.000000  99.000000    99.000000
# mean   4.664620e+09  5.200763e+05   3.404040   1.989899  2086.383838
# std    2.935212e+09  3.061939e+05   0.794358   0.729236   864.592421
# min    1.600040e+07  1.530000e+05   2.000000   1.000000   770.000000
# 25%    1.914950e+09  3.070000e+05   3.000000   1.500000  1410.000000
# 50%    4.036801e+09  4.300000e+05   3.000000   2.000000  1900.000000
# 75%    7.337325e+09  6.562500e+05   4.000000   2.500000  2570.000000
# max    9.822700e+09  2.000000e+06   5.000000   4.500000  5420.000000
#
#             sqft_lot     floors
# count      99.000000  99.000000
# mean    11478.818182   1.464646
# std     14655.249813   0.511363
# min      1044.000000   1.000000
# 25%      5000.000000   1.000000
# 50%      6720.000000   1.500000
# 75%      9823.000000   2.000000
# max    101930.000000   3.000000

# %%
#General info about Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21607 entries, 0 to 21606
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           99 non-null     float64
#  1   date         99 non-null     object
#  2   price        99 non-null     float64
#  3   bedrooms     99 non-null     float64
#  4   bathrooms    99 non-null     float64
#  5   sqft_living  99 non-null     float64
#  6   sqft_lot     99 non-null     float64
#  7   floors       99 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 1.3+ MB

# %%
#df.head()
df.head(10)
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7.129301e+09  20141013T000000   221900.0       3.0       1.00       1180.0
# 1  6.414100e+09  20141209T000000   538000.0       3.0       2.25       2570.0
# 2  5.631500e+09  20150225T000000   180000.0       2.0       1.00        770.0
# 3  2.487201e+09  20141209T000000   604000.0       4.0       3.00       1960.0
# 4  1.954401e+09  20150218T000000   510000.0       3.0       2.00       1680.0
# 5  7.237550e+09  20140512T000000  1230000.0       4.0       4.50       5420.0
# 6  1.321400e+09  20140627T000000   257500.0       3.0       2.25       1715.0
# 7  2.008000e+09  20150115T000000   291850.0       3.0       1.50       1060.0
# 8  2.414600e+09  20150415T000000   229500.0       3.0       1.00       1780.0
# 9  3.793500e+09  20150312T000000   323000.0       3.0       2.50       1890.0
#
#    sqft_lot  floors
# 0    5650.0     1.0
# 1    7242.0     2.0
# 2   10000.0     1.0
# 3    5000.0     1.0
# ...

# %%
#df.tail()
df.tail(10)
# Out:
#        id date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 21597 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21598 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21599 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21600 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21601 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21602 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21603 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21604 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21605 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21606 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN

# %%
df
# Out:
#                  id             date     price  bedrooms  bathrooms  \
# 0      7.129301e+09  20141013T000000  221900.0       3.0       1.00
# 1      6.414100e+09  20141209T000000  538000.0       3.0       2.25
# 2      5.631500e+09  20150225T000000  180000.0       2.0       1.00
# 3      2.487201e+09  20141209T000000  604000.0       4.0       3.00
# 4      1.954401e+09  20150218T000000  510000.0       3.0       2.00
# ...             ...              ...       ...       ...        ...
# 21602           NaN              NaN       NaN       NaN        NaN
# 21603           NaN              NaN       NaN       NaN        NaN
# 21604           NaN              NaN       NaN       NaN        NaN
# 21605           NaN              NaN       NaN       NaN        NaN
# 21606           NaN              NaN       NaN       NaN        NaN
#
#        sqft_living  sqft_lot  floors
# 0           1180.0    5650.0     1.0
# 1           2570.0    7242.0     2.0
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors'],
#       dtype='object')

# %%
df.date
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21602                NaN
# 21603                NaN
# 21604                NaN
# 21605                NaN
# 21606                NaN
# Name: date, Length: 21607, dtype: object

# %%
df[['date', 'price', 'bedrooms']]
# Out:
#                   date     price  bedrooms
# 0      20141013T000000  221900.0       3.0
# 1      20141209T000000  538000.0       3.0
# 2      20150225T000000  180000.0       2.0
# 3      20141209T000000  604000.0       4.0
# 4      20150218T000000  510000.0       3.0
# ...                ...       ...       ...
# 21602              NaN       NaN       NaN
# 21603              NaN       NaN       NaN
# 21604              NaN       NaN       NaN
# 21605              NaN       NaN       NaN
# 21606              NaN       NaN       NaN
#
# [21607 rows x 3 columns]

# %%
df.price.max()
# Out:
# 2000000.0

# %%
df.price.min()
# Out:
# 153000.0

# %% [markdown]
# ### Data Cleaning OR Data Munging

# %%
df.fillna(0, inplace = True)
df.price.mean()
# Out:
# 2382.9108622205767

# %% [markdown]
# ### Replace Values

# %%
df['price'].replace(to_replace = np.nan, value = 0, inplace =True)

# %%
df.price.isnull().sum()
# Out:
# 0

# %%
df.price.sum()
# Out:
# 51487555.0

# %%
df.bathrooms.count()
# Out:
# 21607

# %%
df.bathrooms.unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        0.  ])

# %%
df.price.value_counts()
# Out:
# 0.0         21508
# 650000.0        2
# 430000.0        2
# 360000.0        2
# 199000.0        1
#             ...
# 210490.0        1
# 323000.0        1
# 580500.0        1
# 243500.0        1
# 450000.0        1
# Name: price, Length: 97, dtype: int64

# %%
df[df.price == df.price.max()]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 21  2.524049e+09  20140826T000000  2000000.0       3.0       2.75
#
#     sqft_living  sqft_lot  floors
# 21       3050.0   44867.0     1.0

# %%
# df['price'][df['bathrooms'] == '3.00']
df['date'] [df['bathrooms'] == 3.00]
# Out:
# 3     20141209T000000
# 15    20150124T000000
# 59    20150223T000000
# Name: date, dtype: object

# %%
df[['date', 'bedrooms']][df['bathrooms'] == 4.00]
# Out:
#                date  bedrooms
# 75  20141105T000000       4.0

# %%
df.set_index('date', inplace=True)

# %%
df
# Out:
#                            id     price  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7.129301e+09  221900.0       3.0       1.00       1180.0
# 20141209T000000  6.414100e+09  538000.0       3.0       2.25       2570.0
# 20150225T000000  5.631500e+09  180000.0       2.0       1.00        770.0
# 20141209T000000  2.487201e+09  604000.0       4.0       3.00       1960.0
# 20150218T000000  1.954401e+09  510000.0       3.0       2.00       1680.0
# ...                       ...       ...       ...        ...          ...
# 0                0.000000e+00       0.0       0.0       0.00          0.0
# 0                0.000000e+00       0.0       0.0       0.00          0.0
# 0                0.000000e+00       0.0       0.0       0.00          0.0
# 0                0.000000e+00       0.0       0.0       0.00          0.0
# 0                0.000000e+00       0.0       0.0       0.00          0.0
#
#                  sqft_lot  floors
# date
# ...

# %%
df.loc['20150218T000000']
# Out:
# id             1.954401e+09
# price          5.100000e+05
# bedrooms       3.000000e+00
# bathrooms      2.000000e+00
# sqft_living    1.680000e+03
# sqft_lot       8.080000e+03
# floors         1.000000e+00
# Name: 20150218T000000, dtype: float64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                   date            id     price  bedrooms  bathrooms  \
# 0      20141013T000000  7.129301e+09  221900.0       3.0       1.00
# 1      20141209T000000  6.414100e+09  538000.0       3.0       2.25
# 2      20150225T000000  5.631500e+09  180000.0       2.0       1.00
# 3      20141209T000000  2.487201e+09  604000.0       4.0       3.00
# 4      20150218T000000  1.954401e+09  510000.0       3.0       2.00
# ...                ...           ...       ...       ...        ...
# 21602                0  0.000000e+00       0.0       0.0       0.00
# 21603                0  0.000000e+00       0.0       0.0       0.00
# 21604                0  0.000000e+00       0.0       0.0       0.00
# 21605                0  0.000000e+00       0.0       0.0       0.00
# 21606                0  0.000000e+00       0.0       0.0       0.00
#
#        sqft_living  sqft_lot  floors
# 0           1180.0    5650.0     1.0
# 1           2570.0    7242.0     2.0
# ...

# %%
df.set_index('bathrooms', inplace=True)

# %%
df
# Out:
#                       date            id     price  bedrooms  sqft_living  \
# bathrooms
# 1.00       20141013T000000  7.129301e+09  221900.0       3.0       1180.0
# 2.25       20141209T000000  6.414100e+09  538000.0       3.0       2570.0
# 1.00       20150225T000000  5.631500e+09  180000.0       2.0        770.0
# 3.00       20141209T000000  2.487201e+09  604000.0       4.0       1960.0
# 2.00       20150218T000000  1.954401e+09  510000.0       3.0       1680.0
# ...                    ...           ...       ...       ...          ...
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
#
#            sqft_lot  floors
# bathrooms
# ...

# %% [markdown]
# ### In general index must be UNIQUE

# %%
df.loc[2.00]
# Out:
#                       date            id     price  bedrooms  sqft_living  \
# bathrooms
# 2.0        20150218T000000  1.954401e+09  510000.0       3.0       1680.0
# 2.0        20150312T000000  1.175001e+09  530000.0       5.0       1810.0
# 2.0        20140731T000000  1.875500e+09  395000.0       3.0       1890.0
# 2.0        20141103T000000  1.202000e+09  233000.0       3.0       1710.0
# 2.0        20141230T000000  2.768000e+09  640000.0       4.0       2360.0
# 2.0        20150105T000000  1.049000e+09  325000.0       3.0       1260.0
# 2.0        20140610T000000  8.820901e+09  571000.0       4.0       2750.0
#
#            sqft_lot  floors
# bathrooms
# 2.0          8080.0     1.0
# 2.0          4850.0     1.5
# 2.0         14040.0     2.0
# 2.0          4697.0     1.5
# 2.0          6000.0     2.0
# 2.0          5612.0     1.0
# 2.0          7807.0     1.5

# %%
df.head()
# Out:
#                       date            id     price  bedrooms  sqft_living  \
# bathrooms
# 1.00       20141013T000000  7.129301e+09  221900.0       3.0       1180.0
# 2.25       20141209T000000  6.414100e+09  538000.0       3.0       2570.0
# 1.00       20150225T000000  5.631500e+09  180000.0       2.0        770.0
# 3.00       20141209T000000  2.487201e+09  604000.0       4.0       1960.0
# 2.00       20150218T000000  1.954401e+09  510000.0       3.0       1680.0
#
#            sqft_lot  floors
# bathrooms
# 1.00         5650.0     1.0
# 2.25         7242.0     2.0
# 1.00        10000.0     1.0
# 3.00         5000.0     1.0
# 2.00         8080.0     1.0

# %% [markdown]
# ### Rename a Column

# %%
df.rename(columns = {'date' : 'Dates'}, inplace = True)

# %%
df.head()
# Out:
#                      Dates            id     price  bedrooms  sqft_living  \
# bathrooms
# 1.00       20141013T000000  7.129301e+09  221900.0       3.0       1180.0
# 2.25       20141209T000000  6.414100e+09  538000.0       3.0       2570.0
# 1.00       20150225T000000  5.631500e+09  180000.0       2.0        770.0
# 3.00       20141209T000000  2.487201e+09  604000.0       4.0       1960.0
# 2.00       20150218T000000  1.954401e+09  510000.0       3.0       1680.0
#
#            sqft_lot  floors
# bathrooms
# 1.00         5650.0     1.0
# 2.25         7242.0     2.0
# 1.00        10000.0     1.0
# 3.00         5000.0     1.0
# 2.00         8080.0     1.0

# %% [markdown]
# ### One Hot Encoding

# %%
dummies = pd.get_dummies(df.floors)

# %%
df = pd.concat([df,dummies],axis='columns')

# %%
df = df.drop(['floors'], axis='columns')
df
# Out:
#                      Dates            id     price  bedrooms  sqft_living  \
# bathrooms
# 1.00       20141013T000000  7.129301e+09  221900.0       3.0       1180.0
# 2.25       20141209T000000  6.414100e+09  538000.0       3.0       2570.0
# 1.00       20150225T000000  5.631500e+09  180000.0       2.0        770.0
# 3.00       20141209T000000  2.487201e+09  604000.0       4.0       1960.0
# 2.00       20150218T000000  1.954401e+09  510000.0       3.0       1680.0
# ...                    ...           ...       ...       ...          ...
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
# 0.00                     0  0.000000e+00       0.0       0.0          0.0
#
#            sqft_lot  0.0  1.0  1.5  2.0  3.0
# bathrooms
# ...

# %% [markdown]
# ### Spliting using Pandas

# %%
df1 = df.copy()

# %%
train = df1.sample(frac=0.75, random_state=1)
test = df1.drop(train.index)

# %%
test.count()

# %%
df.to_csv('20-07-2020_ML_Task_Avinash Vijayvargiya.csv')
